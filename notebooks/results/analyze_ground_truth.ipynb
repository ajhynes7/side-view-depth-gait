# %%
import os

os.chdir('../..')

# %%
import pandas as pd

# %%
df_hypo = pd.read_pickle('data/kinect/processed/hypothesis/2014-12-03_P007_Post_000.pkl')

# %%
df_hypo.L_F.dropna()
# Out:
# Frame
# 31      [[47.03173050603279, 116.03683751638545, 344.0]]
# 73      [[101.84673934607892, 94.58260496449468, 351.0]]
# 93     [[102.46314798125508, 96.87974115184988, 352.4...
# 97     [[-134.6752548940234, -10.966963005670644, 280...
# 98     [[-132.79661630952458, -10.301497424556501, 27...
# 99     [[-128.08318126315032, -5.173057891069837, 278...
# 100    [[-126.89015568739751, -40.52746748444232, 264...
# 101    [[-124.54723122507912, -32.892425997477076, 26...
# 102    [[-122.58475886925021, -39.7609991149693, 261....
# 103    [[-126.16344744658994, -80.0906653403217, 270....
# 104    [[-115.90682939290156, -81.86746208489606, 269...
# 105    [[-115.57529140658818, -75.3301864596252, 266....
# 106    [[-104.65800985067078, -81.11025166787323, 267...
# 107    [[-92.17841551728858, -81.44892468922319, 269....
# 108    [[-90.36610741042266, -81.70617361989672, 269....
# 109    [[-92.89780723053731, -81.24004059854232, 267....
# ...

# %%
df_truth = pd.read_pickle('results/dataframes/df_truth.pkl')

# %%
df_truth.groupby('trial_name').count()
# Out:
#                           HEAD  L_HIP  R_HIP  L_THIGH  R_THIGH  L_KNEE  \
# trial_name
# 2014-12-03_P005_Post_002   191    191    191      191      191     191
# 2014-12-03_P007_Post_000   199    199    199      199      199     199
#
#                           R_KNEE  L_CALF  R_CALF  L_FOOT  R_FOOT
# trial_name
# 2014-12-03_P005_Post_002     191     191     191     191     191
# 2014-12-03_P007_Post_000     199     199     199     199     199

# %%
df_truth.shape
# Out:
# (390, 11)

# %%
df_truth.shape
# Out:
# (390, 11)
