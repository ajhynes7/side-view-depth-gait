# %%
import numpy as np

# %%
np.random.random(3)
# Out:
# array([0.04916838, 0.45242245, 0.09882306])

# %%
np.random.randint(-2, 2, (10, 2))
# Out:
# array([[ 1, -1],
#        [-2,  0],
#        [-2,  1],
#        [ 1, -2],
#        [-2,  0],
#        [-2,  1],
#        [ 0, -1],
#        [-1, -2],
#        [ 0, -2],
#        [ 0,  0]])

# %%
np.random.uniform(-2, 2, 3)
# Out:
# array([ 1.43744517, -0.38318184,  0.64492919])

# %%
np.random.randint(-3, 3)
# Out:
# -3
